# %%
import json
import pandas as pd

# %%
data = pd.read_json("tweets2.json")

# %%
data.shape
# Out:
# (383, 10)

# %%
data2 = pd.read_json("tweets3.json")

# %%
data2.drop("html",axis=1,inplace=True)

# %%
data2['text'][3]
# Out:
# 'VHP workers protest against Narendra Modi - NDTV.com: VHP workers protest against Narendra ModiNDTV.com&.. http://tinyurl.com/5m9udk'

# %%
data2.shape
# Out:
# (1849, 9)

# %%
data2
# Out:
#                              fullname          id  likes  replies  retweets  \
# 0                        indiaupdates   991402979      0        0         0
# 1                             bjpnews   991364218      0        0         0
# 2                           thaindian   991354337      0        0         0
# 3                     News from India   988855300      0        0         0
# 4                     GoogleNewsIndia   988824922      0        0         0
# 5                               pawst   981747227      0        0         0
# 6                        Viral Sachde   970863429      0        0         0
# 7                               pawst   968924434      0        0         0
# 8                          business88   965524782      0        0         0
# 9                        welcome2pune   964674842      0        0         0
# 10                          thaindian   957356730      0        0         0
# ...

# %%
data3 = pd.read_json("elections.json")

# %%
data3
# Out:
#                          fullname  \
# 0                        24Trends
# 1               Thread Reader App
# 2                     Ksk Academy
# 3                   Media Scanner
# 4                        24Trends
# 5             Somsirsa Chatterjee
# 6                News18 Elections
# 7                     Kamran Khan
# 8             Indian News Updates
# 9               Thread Reader App
# 10                            SRK
# 11                 Amit Kumar Das
# 12              Siddharth Gaikwad
# 13                     Cine Blitz
# 14                 Vishal Kaushik
# 15           Chowkidar Akhilanand
# 16             T. LAKSHMINARAYANA
# 17          Chowkidar Aravind Sai
# 18              Vandana D Khandal
# 19              Vandana D Khandal
# 20                       24Trends
# 21              Thread Reader App
# 22                    Ksk Academy
# 23                  Media Scanner
# 24                       24Trends
# 25            Somsirsa Chatterjee
# ...

# %%
shashi = pd.read_json("shashi.json")

# %%
shashi.shape
# Out:
# (1027, 10)

# %%
pappu = pd.read_json('rahul.json')

# %%
list(pappu['text'])
# Out:
# ['लो कर लो बात,  ये खुद्द शाहीदोनको राजनीती मे इस्टेमाल करंगे, लेकी न और कोई करे तो ग ल त.',
#  'जेल के लिये बीमार का मतलब ही नही है जब कोर्ट ने बरी करते हुये रिहा कर दिया कि आरोप साबित ही नही होते कोई सबूत ही नही है',
#  'So as Mohan Chand Sharma.. \n\nYour Italian Mother cried for Terrorists after Batla house Encounter..',
#  'अबे bsdk वो भाजपा का नहीं तेरे ही पार्टी का कोई नेता था',
#  "Don't vote for nyay\n\n#ModiLaoDeshBanao\n#ModiHaiTohMumkinHai\n#PhirEkBaarModiSarakar",
#  'Chal chal pumcher laga',
#  'Rahul should affix a tail and jump around to garner votes.',
#  'Is @RamaNewDelhi a Muslim in disguise similar to @RahulGandhi ?',
#  '@RahulGandhi that reply is to you!',
#  'Karkare ko bhi cong ne hi mrwaya. He & 2other officers were "shot dead",\nEVEN BEFORE reaching at site of terrorist attack. HOW? Shayad vo Jaldi hi cong ka koi raz fash krne wala tha. Ya vo ye jan gaya tha ki 26/11 terrorist attack congress ne hi pigstan se mil kar karwaya tha',
#  'WTF! Lame',
# ...

# %%
latest = pd.read_json("ls.json")

# %%
latest
# Out:
#                          fullname  \
# 0                        NamoTube
# 1                          DailyO
# 2                  Esther Proctor
# 3                    Pankaj Singh
# 4                      Srinivasan
# 5                Peggy B. Cosenza
# 6                West Bengal News
# 7                       IndiaNews
# 8                        OneIndia
# 9                        Chi Tran
# 10           chowkidar Siddu math
# 11              South Asians News
# 12                   VisHal Patel
# 13                       Narahari
# 14                 News Summed Up
# 15              South Asians News
# 16                         Pratik
# 17            ETimeTableResult.in
# 18           ALLURI DIVAKAR REDDY
# 19                      TIMES NOW
# 20                 Tamizh Rasigan
# 21                      Avalurian
# 22    Economic & Political Weekly
# 23             Priya Ramachandran
# 24             Priya Ramachandran
# 25                      The Hindu
# ...

# %%
text = list(latest['text'])

# %%
text[20]
# Out:
# 'Rajinikanth said: I and my party will not contest the Lok Sabha elections of 2019 https://goo.gl/3F1BiA\xa0'

# %%
dfObj = latest.sort_values(by ='likes',ascending=False)

# %%
dfobj2 = dfObj[dfObj["likes"]>10]

# %%
dfobj2
# Out:
#                            fullname  \
# 5297        Chowkidar Narendra Modi
# 1306                       Congress
# 2905                    OpIndia.com
# 2150                            ANI
# 2901                 Nupur J Sharma
# 4316                    Delhi Times
# 1147                    Jan Ki Baat
# 1515                 Chowkidar Ashu
# 2120     Vikas Bhadauria (ABP News)
# 3253                   Nadeem Javed
# 904                     Juhie Singh
# 1728                      TIMES NOW
# 1532         We the People of India
# 2265                 Nupur J Sharma
# 681                   Raghav4Change
# 858                        The Wire
# 2708                         Dibang
# 929             SamajwadiPartyMedia
# 294                   Anand Shekhar
# 900                   Aashish Yadav
# 1389                       Republic
# 2181                    OpIndia.com
# 2131                       ABP News
# 1275                 Delhi Congress
# 4734                       Republic
# ...

# %%
len(dfobj2["text"].unique())
# Out:
# 329

# %%
rahul = pd.read_json("rahul.json")

# %%
rahul.sort_values(by="likes",ascending=False,inplace=True)

# %%
rahul_filtered = rahul[rahul["likes"]>10]

# %%
rahul_filtered.shape
# Out:
# (195, 10)

# %%
rahul_text = list(rahul_filtered['text'])

# %%
rahul_text[6]
# Out:
# 'So as Mohan Chand Sharma.. \n\nYour Italian Mother cried for Terrorists after Batla house Encounter..'

# %%
zeenews = pd.read_json("zeenews.json")

# %%
zeenews
# Out:
#           fullname                                               html  \
# 0         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 1         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 2    Mimansa Malik  <p class="TweetTextSize TweetTextSize--normal ...
# 3         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 4         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 5         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 6         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 7         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 8         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 9         Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 10        Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# 11        Zee News  <p class="TweetTextSize TweetTextSize--normal ...
# ...

# %%
zeenews.sort_values(by="likes",ascending=False,inplace=True)

# %%
zeenews = zeenews[zeenews["likes"]>=5]

# %%
list(zeenews['text'])[4]
# Out:
# 'ममता के ‘अहंकार’ पर क़ानून का ‘कोड़ा’?\nदीदी के ‘अहम’ पर अवार्ड वापसी गैंग ख़ामोश?\n#TaalThokKe स्पेशल एडिशन @ZeeNews 6 PM'

# %%
zeenews.shape
# Out:
# (823, 10)
