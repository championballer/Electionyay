# %%
import json
import pandas as pd

# %%
data = pd.read_json("tweets2.json")

# %%
data.shape
# Out:
# (383, 10)

# %%
data2 = pd.read_json("tweets3.json")

# %%
data2.drop("html",axis=1,inplace=True)

# %%
data2['text'][3]
# Out:
# 'VHP workers protest against Narendra Modi - NDTV.com: VHP workers protest against Narendra ModiNDTV.com&.. http://tinyurl.com/5m9udk'

# %%
data2.shape
# Out:
# (1849, 9)

# %%
data2
# Out:
#                              fullname          id  likes  replies  retweets  \
# 0                        indiaupdates   991402979      0        0         0
# 1                             bjpnews   991364218      0        0         0
# 2                           thaindian   991354337      0        0         0
# 3                     News from India   988855300      0        0         0
# 4                     GoogleNewsIndia   988824922      0        0         0
# 5                               pawst   981747227      0        0         0
# 6                        Viral Sachde   970863429      0        0         0
# 7                               pawst   968924434      0        0         0
# 8                          business88   965524782      0        0         0
# 9                        welcome2pune   964674842      0        0         0
# 10                          thaindian   957356730      0        0         0
# ...

# %%
data3 = pd.read_json("elections.json")

# %%
data3
# Out:
#                          fullname  \
# 0                        24Trends
# 1               Thread Reader App
# 2                     Ksk Academy
# 3                   Media Scanner
# 4                        24Trends
# 5             Somsirsa Chatterjee
# 6                News18 Elections
# 7                     Kamran Khan
# 8             Indian News Updates
# 9               Thread Reader App
# 10                            SRK
# 11                 Amit Kumar Das
# 12              Siddharth Gaikwad
# 13                     Cine Blitz
# 14                 Vishal Kaushik
# 15           Chowkidar Akhilanand
# 16             T. LAKSHMINARAYANA
# 17          Chowkidar Aravind Sai
# 18              Vandana D Khandal
# 19              Vandana D Khandal
# 20                       24Trends
# 21              Thread Reader App
# 22                    Ksk Academy
# 23                  Media Scanner
# 24                       24Trends
# 25            Somsirsa Chatterjee
# ...
