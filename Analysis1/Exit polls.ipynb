# %%
import pandas as pd
import json

# %%
data = pd.read_json("exit.json")

# %%
data = data.sort_values(by="likes",ascending=False)

# %%
data
# Out:
#                                           fullname  \
# 0                                      👮AnuRag  🇮🇳
# 1                                      Ramesh Babu
# 2     Chowkidar Dr R Hindusthani #MeinBhiChowkidar
# 3                                Zachary Borthwick
# 4                                    P.V.SIVAKUMAR
# 5                                   Brijesh Pandey
# 6                                    Sanjeev Verma
# 7                                    Eddy Jokovich
# 8                                    Michael Järvå
# 9                                      Bucolic_man
# 10                               Election News Bay
# 11                                 Adam Y. Soliman
# 12                                  Mohammed Tayeb
# 13                                        sundarji
# 14                                            Amit
# 15                                        #23rdMay
# 16                                           N'Pal
# ...

# %%
data.sort_values(by=["timestamp","likes"],ascending=False,inplace=True)

# %%
data
# Out:
#                      fullname  \
# 559              nikhil wagle
# 1344              Manak Gupta
# 214             Kunal Saraogi
# 241             Shekhar Gupta
# 1146  Ishkaran Singh Bhandari
# 1331           Sagarika Ghose
# 1358                  meghnad
# 1123     Chowkidar Anuj Gupta
# 479            Milan Vaishnav
# 1095                    Sagar
# 1001            Nigel D'Souza
# 529          Paresh Rawal fan
# 253               Maithun HMP
# 347       Tavleen Singh Aroor
# 1184              barkha dutt
# 941                 Paul Kidd
# 433               Mufti Islah
# 1034               Shridhar V
# 1198             Mike Carlton
# 450             Sumanth Raman
# 1285                 Republic
# 768           Mikey Nicholson
# 657               K. C. Singh
# 656       Varinder Bansal  🇮🇳
# 819              Holly Byrnes
# 155               Samir Saran
# 195                    नम्रता
# 990           michael_nielsen
# 1430               Hetal Rach
# 295   चौकीदार Totlani Krishan
# ...
