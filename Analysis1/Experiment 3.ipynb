# %%
import pandas as pd
import json
import numpy as np

# %%
data = pd.read_json("elections.json")

# %%
data.head()
# Out:
#             fullname                                               html  \
# 0           24Trends  <p class="TweetTextSize js-tweet-text tweet-te...
# 1  Thread Reader App  <p class="TweetTextSize js-tweet-text tweet-te...
# 2        Ksk Academy  <p class="TweetTextSize js-tweet-text tweet-te...
# 3      Media Scanner  <p class="TweetTextSize js-tweet-text tweet-te...
# 4           24Trends  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                     id  likes  replies  retweets  \
# 0  1089652177885290496      0        0         0
# 1  1089628726994849792      0        0         1
# 2  1089599805549092864      0        0         0
# 3  1089593065428246528      0        0         0
# 4  1089591802439512064      0        0         0
#
#                                                 text           timestamp  \
# 0  Breaking News - Priyanka Gandhi is 'Gorakhpur ... 2019-01-27 22:31:38
# 1  Hello, the unroll you asked for: Thread by @Sa... 2019-01-27 20:58:27
# ...

# %%
dfObj = data.sort_values(by ='likes',ascending=False)

# %%
dfObj
# Out:
#                                 fullname  \
# 32637            Chowkidar Narendra Modi
# 29861            Chowkidar Narendra Modi
# 34649            Chowkidar Narendra Modi
# 17287            Chowkidar Narendra Modi
# 34685            Chowkidar Narendra Modi
# 42259            Chowkidar Narendra Modi
# 25719            Chowkidar Narendra Modi
# 2788                         Kunal Kamra
# 44986            Chowkidar Sushma Swaraj
# 8401                          Ajay Devgn
# 591               Chowkidar Sambit Patra
# 33391                      Anshul Saxena
# 14580                           Congress
# 8597                         Anil Kapoor
# 6600   Chowkidar Shandilya Giriraj Singh
# 26931                  Aarti Tikoo Singh
# 42288                Chowkidar Amit Shah
# 12636                           Congress
# 33073                   Shehzad Jai Hind
# 26187      Chowkidar Ravi Shankar Prasad
# 44208                                BJP
# 11864      Chowkidar Mahesh Vikram Hegde
# ...
